# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# **Gathering Data**

# %%
df = pd.read_csv("income.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %% [markdown]
# **Data Cleaning**

# %%
df.isnull().sum(axis=0)
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.dropna()
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# **Dropping Null Values**

# %% [markdown]
# 1. Removing missing values

# %%
missingvalues = ["?","NaN","N/a","NA","na"]
df = pd.read_csv("income.csv", na_values=missingvalues)

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 5              30  United-States  <=50K

# %%
df.shape
# Out:
# (45222, 15)

# %%
value = df['income'].isnull().values.any()
print(value)
# Out:
# False

# %% [markdown]
# 2. Check if there are any duplicate values

# %%
df.duplicated().value_counts()
# Out:
# False    45175
# True        47
# dtype: int64

# %% [markdown]
# 2(a) Dropping the 47 duplicate values

# %%
df = df.drop_duplicates()

# %%
display(df.drop_duplicates())
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [45175 rows x 15 columns]

# %%
df.shape
# Out:
# (45175, 15)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 2(b) Dropping the column "fnlgwt" as it doesn't provide any insight from that column

# %%
df.drop(df.columns[[2]], axis=1, inplace=True)

# %%
df.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 5   34    Private          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 5              30  United-States  <=50K

# %%
df.shape
# Out:
# (45175, 14)

# %% [markdown]
# **Exploratory Data Analysis**

# %%
print(df.dtypes)
# Out:
# age                 int64
# workclass          object
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data = df["age"])
plt.ylabel("age")
plt.title("Box Plot for Age")
# Out:
# Text(0.5, 1.0, 'Box Plot for Age')

# %% [markdown]
# The median value of age is nearly 38.Also, the values of age is in between 18 and 75 and most of the values are from 28 to 48, which means **most employed persons** have ages in between **28 and 48**.

# %%
plt.figure(figsize=(12,5))
sns.histplot(data = df, x='workclass')
plt.title("Histogram on Workclass")
# Out:
# Text(0.5, 1.0, 'Histogram on Workclass')

# %% [markdown]
# Most of the employees are from private sector

# %%
df.groupby('workclass').size().plot(kind='pie', label = "Categories of Workclass")
# Out:
# <AxesSubplot:ylabel='Categories of Workclass'>

# %% [markdown]
# From the pie-plot, we can derive that most of the employees are from **private sector**.

# %%
ax = sns.histplot(x= 'educational-num',data = df, color='Cyan',bins=20)
ax.set_xticks(range(1,16))

#specify axis labels
plt.xlabel('Academic Years')
plt.ylabel('Count')
plt.title('Histogram on Years of Education')

#display histogramplot
plt.show()

# %%
df['educational-num'].value_counts()
# Out:
# 9     14770
# 10     9887
# 13     7559
# 14     2513
# 11     1958
# 7      1619
# 12     1507
# 6      1223
# 4       822
# 15      785
# 5       676
# 8       575
# 16      544
# 3       447
# 2       220
# 1        70
# Name: educational-num, dtype: int64

# %% [markdown]
# According to the above histogram, nearly **33%** of people have **9 years of academic experience** before starting a job.

# %%
sns.countplot(x= 'marital-status',data = df, color='red')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Never-married'),
#   Text(1, 0, 'Married-civ-spouse'),
#   Text(2, 0, 'Widowed'),
#   Text(3, 0, 'Separated'),
#   Text(4, 0, 'Divorced'),
#   Text(5, 0, 'Married-spouse-absent'),
#   Text(6, 0, 'Married-AF-spouse')])

# %% [markdown]
# **Married-civ-spouse** means married and is a spouse of civilian are the **highest number** of people with a job.

# %%
plt.figure(figsize=(7,5))
sns.barplot(y = df['education'].unique(),x = df['education'].value_counts()).set(ylabel = "Education Background",title = "Bar plot on different Educations")
# Out:
# [Text(0, 0.5, 'Education Background'),
#  Text(0.5, 1.0, 'Bar plot on different Educations')]

# %% [markdown]
# Based on the barplot, the **minimum education** of any person that landed in a job is **11th standard**.

# %%
sns.violinplot(y = df['income'], x = df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='income'>

# %% [markdown]
# Individuals between the ages of **23 and 46** are most likely to have an **income of less than or equal to 50K**, according to the violin plot. Furthermore, people begin **earning more than 50K at the age of 35 and continue to do so until they are 52**.

# %%
sns.barplot(y = df['occupation'].unique(),x = df['occupation'].value_counts()).set(xlabel = "Count", ylabel = "Occupation",title = "Bar plot on different Occupations")
# Out:
# [Text(0.5, 0, 'Count'),
#  Text(0, 0.5, 'Occupation'),
#  Text(0.5, 1.0, 'Bar plot on different Occupations')]

# %% [markdown]
# From the above findings,almost **40% jobs** are available for machine operator and inspector, farming-fishing and Protective Service roles and people working for it.

# %%
plt.figure(figsize=(7,5))
sns.kdeplot(df['capital-loss'])
plt.title("KDE on Capital Loss")
# Out:
# Text(0.5, 1.0, 'KDE on Capital Loss')

# %% [markdown]
# From the Kernel Density Estimation, it is clear that there are **no outliers** for the Capital loss column. Also, the mean values is near zero which means that there is **no loss incurred by individuals** from the sale of a capital asset, such as a stock, bond, or real estate.

# %%
sns.stripplot(x = df['age'], y = df['income'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='income'>

# %% [markdown]
# From the strip plot, people with **age less than 20 and more than 70** mostly have income less than 50K.

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), center=0, cmap='BrBG', annot=True)
plt.title("Heat Map of all the Quantitative Values")
# Out:
# Text(0.5, 1.0, 'Heat Map of all the Quantitative Values')

# %% [markdown]
# From the heat map, we can say that there is no much correlation between the quantitative variables, but there is least correlation in few columns which are **educational-num** and **hours-per-week**, **capital-gain** and **educational-num** & **age** and **hours-per-week**.

# %%
sns.scatterplot(data = df, x ="hours-per-week", y="age")
plt.title("Relation between Age and Hours per Week")
# Out:
# Text(0.5, 1.0, 'Relation between Age and Hours per Week')

# %% [markdown]
# People above **80** years of age spend less time working over week.

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data = df['hours-per-week'])
plt.title("Line plot on Hours spent on work for a week by an Individual")
# Out:
# Text(0.5, 1.0, 'Line plot on Hours spent on work for a week by an Individual')

# %% [markdown]
# Almost every individual spends **10 to 70 hours** in a week on their job.

# %%
sns.pairplot(data = df)

# %% [markdown]
# **API EXTRACTION AND CONVERTING TO VECTORIZED DATA**

# %%
import requests

url = ('https://newsapi.org/v2/everything?''q=adults income&''apiKey=18071091481841b1910d5ae638bfef59')

response = requests.get(url)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
jsontxt = response.json()

# %%
response.content
# Out:
# b'{"status":"ok","totalResults":1575,"articles":[{"source":{"id":"time","name":"Time"},"author":"Mariah Espada","title":"TikTok Is Celebrating \xe2\x80\x98DINKs\xe2\x80\x99: Double Income No Kids Households","description":"Fertility rates have been declining in the U.S. and there is a growing share of adults in the U.S. that don\xe2\x80\x99t plan to have children","url":"https://time.com/6250834/dink-tiktok-double-income-no-kids/","urlToImage":"https://api.time.com/wp-content/uploads/2023/01/dinks-tiktok.jpg?quality=85&crop=0px%2C0px%2C2400px%2C1256px&resize=1200%2C628&strip","publishedAt":"2023-01-27T21:42:39Z","content":"The days of family channels being the internet\xe2\x80\x99s ideal family arrangement are behind us. Instead, apps like TikTok are making room for DINKS, an acronym for households with double incomes, and no kid\xe2\x80\xa6 [+5077 chars]"},{"source":{"id":"ars-technica","name":"Ars Technica"},"author":"Beth Mole","title":"US still has the worst, most expensive health care of any high-income country","description":"US health care has lagged peers for years, and the pandemic made things worse.","url":"https://arstechnica.com/science/2023/01/us-still-has-the-worst-most-expensive-health-care-of-any-high-income-country/","urlToImage":"https://cdn.arstechnica.net/wp-content/uploads/2022/05/GettyImages-1341226201-760x380.jpeg","publishedAt":"2023-01-31T21:18:27Z","content":"Enlarge/ A woman watches white flags on the National Mall on September 18, 2021, in Washington, DC. Over 660,000 white flags were installed here to honor Americans who have lost their lives to COVID-\xe2\x80\xa6 [+5442 chars]"},{"source":{"id":null,"name":"The Guardian"},"author":"Phillip Inman","title":"Low income households miss out on \xc2\xa350m to help pay energy bills","description":"Campaigners call on ministers to allow vulnerable people a second chance as aid goes unclaimedOne in five households with prepayment meters have missed out on government energy vouchers to help pay bills.According to new figures, a total of about 760,000 vouc\xe2\x80\xa6","url":"https://www.theguardian.com/business/2023/feb/07/low-income-households-miss-out-on-50m-to-help-pay-energy-bills","urlToImage":"https://i.guim.co.uk/img/media/c609cda8498f326264c75d51e4ee2bdddb222cd5/0_0_4272_2563/master/4272.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=9a11ce17b79f3c961ead99ad4f8364e5","publishedAt":"2023-02-07T18:47:39Z","content":"One in five households with prepayment meters have missed out on government energy vouchers to help pay bills.\\r\\nAccording to new figures, a total of about 760,000 vouchers went unclaimed in October a\xe2\x80\xa6 [+2882 chars]"},{"source":{"id":null,"name":"Boing Boing"},"author":"Jason Weisberger","title":"NIMBY proposes using disabled people as a shield against the \\"poor\\"","description":"NIMBY-ism may have been born in New Hampshire and Michigan, but Northern California has perfected it. Under State law, Hillsborough, California needs to provide a number of \\"low-income\\" housing units, where \\"low-income\\" is largely based on the average income \xe2\x80\xa6","url":"https://boingboing.net/2023/02/10/nimby-proposes-using-disabled-people-as-a-shield-against-the-poor.html","urlToImage":"https://i0.wp.com/boingboing.net/wp-content/uploads/2022/10/shutterstock_33885607.jpg?fit=1200%2C857&ssl=1","publishedAt":"2023-02-10T15:49:53Z","content":"NIMBY-ism may have been born in New Hampshire and Michigan, but Northern California has perfected it. Under State law, Hillsborough, California needs to provide a number of \\"low-income\\" housing units\xe2\x80\xa6 [+2025 chars]"},{"source":{"id":"business-insider","name":"Business Insider"},"author":"insider@insider.com (Juliana Kaplan)","title":"Meet the DINKWADs: The TikTok legion making everyone jealous with their double incomes, no kids, and a dog","des ...

# %%
filename="Adult_Income_Headlines.csv"
MyFILE=open(filename,"w")
WriteThis="Date,Source,Title,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
MyFILE=open(filename, "a")

# %%
import re
for items in jsontxt["articles"]:
    Source=items["source"]["id"]    
    Date=items["publishedAt"]
    NewDate=Date.split("T")
    Date=NewDate[0]
    ## CLEAN the Title
    ##Replace punctuation with space
    # Accept one or more copies of punctuation         
    # plus zero or more copies of a space
    # and replace it with a single space
    Title=items["title"]
    Title=re.sub(r'[,.;@#?!&$\-\']+', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(' +', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(r'\"', ' ', Title, flags=re.IGNORECASE)
    
    # and replace it with a single space
    ## NOTE: Using the "^" on the inside of the [] means
    ## we want to look for any chars NOT a-z or A-Z and replace
    ## them with blank. This removes chars that should not be there.
    Title=re.sub(r'[^a-zA-Z]', " ", Title, flags=re.VERBOSE)
    Title=Title.replace(',', '')
    Title=' '.join(Title.split())
    Title=re.sub("\n|\r", "", Title)
    ##----------------------------------------------------------
    
    Headline=items["description"]
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if len(wd)>3])
    WriteThis=str(Date)+","+str(Source)+","+ str(Title) + "," + str(Headline) + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
adult_income_api = pd.read_csv(filename, error_bad_lines=False)
print(adult_income_api.head())
# iterating the columns 
for col in adult_income_api.columns: 
    print(col) 
    
print(adult_income_api["Headline"])

## REMOVE any rows with NaN in them
adult_income_api = adult_income_api.dropna()
print(adult_income_api["Headline"])

### Tokenize and Vectorize the Headlines
## Create the list of headlines
HeadlineLIST = []
for next1 in adult_income_api["Headline"]:
    HeadlineLIST.append(next1)

print("The headline list is")
print(HeadlineLIST)
# Out:
#          Date            Source  \
# 0  2023-01-27              time
# 1  2023-01-31      ars-technica
# 2  2023-02-07              None
# 3  2023-02-10              None
# 4  2023-02-04  business-insider
#
#                                                Title  \
# 0  TikTok Is Celebrating DINKs Double Income No K...
# 1  US still has the worst most expensive health c...
# 2  Low income households miss out on m to help pa...
# 3  NIMBY proposes using disabled people as a shie...
# 4  Meet the DINKWADs The TikTok legion making eve...
#
#                                             Headline
# 0  Fertility rates have been declining there grow...
# 1  health care lagged peers years pandemic made t...
# 2  Campaigners call ministers allow vulnerable pe...
# 3  NIMBY have been born Hampshire Michigan Northe...
# 4  Take DINK DINKWAD Double income kids with Amer...
# Date
# Source
# Title
# Headline
# 0     Fertility rates have been declining there grow...
# 1     health care lagged peers years pandemic made t...
# 2     Campaigners call ministers allow vulnerable pe...
# 3     NIMBY have been born Hampshire Michigan Northe...
# 4     Take DINK DINKWAD Double income kids with Amer...
#                             ...
# 95    partisan Congressional Budget Office cautioned...
# 96    recent years there been huge rising demand don...
# 97    Across spheres life into evolutionary mismatch...
# 98    Judge Matthew Kacsmaryk amassed litany content...
# 99    What could more concerning than climate change...
# Name: Headline, Length: 100, dtype: object
# 0     Fertility rates have been declining there grow...
# 1     health care lagged peers years pandemic made t...
# 2     Campaigners call ministers allow vulnerable pe...
# 3     NIMBY have been born Hampshire Michigan Northe...
# 4     Take DINK DINKWAD Double income kids with Amer...
#                             ...
# 95    partisan Congressional Budget Office cautioned...
# 96    recent years there been huge rising demand don...
# 97    Across spheres life into evolutionary mismatch...
# 98    Judge Matthew Kacsmaryk amassed litany content...
# 99    What could more concerning than climate change...
# Name: Headline, Length: 100, dtype: object
# The headline list is
# ['Fertility rates have been declining there growing share adults that plan have children', 'health care lagged peers years pandemic made things worse', 'Campaigners call ministers allow vulnerable people second chance goes unclaimedOne five households with prepayment meters have missed government energy vouchers help bills According figures total about vouc', 'NIMBY have been born Hampshire Michigan Northern California perfected Under State Hillsborough California needs provide number income housing units where income largely based average income', 'Take DINK DINKWAD Double income kids with American Dream', 'Young adults living with their parents highest rate decades Four them broke down they spend money they save rent', 'More than decade passed since Mitt Romney lost political support during failed presidential campaign boasting about having binders full women suitable government appointments writing Americans federa', 'Half pharmacists survey report that patients asking which items they without Rising numbers patients England failing collect their medicines asking pharmacists which ones they without because they cannot afford presc', 'When people fear their jobs financial safety inadequate wonder they having smaller families having fewer babies Peak fertility postwar England Wales children woman that dropped', 'Billions gifts loans given when children early adulthood buying first home getting marriedBillions pounds loaned bank help with property purchases boost finances newly married offspring helpi', 'Republicans Iowa Minnesota proposed bills allow kids ages work jobs with shortage labor like meat packing construction', 'Americans today increasingly connected world digital information while smartphones tablets other mobile devices Explore latest patterns trends statistics that have shaped mobile revolution', 'violence highest level since early become concerns many American voters result country debated reforms policing bail sentencing other aspects criminal justice system', 'Yemi Rose founded OfColor after years corporate America Here suggestions employers build equity', 'More than three million adults were forced evacuate their homes past year because hurricanes floods other disasters according Census Bureau', 'President Biden will give Americans progress report four part Unity Agenda which announced last year State Union address', 'bankruptcy filing says approximately million assets unclear many firearms holding where they being kept', 'book Jeff Hobbs author Short Tragic Life Robert Peace looks evolution juvenile justice system America primarily through people statistics', 'Interest rates have risen significantly Borrowing money with personal loan costs someone with credit times much someone with good credit', 'Ultra Processed Foods Linked Increased Risk Cancer Neuroscience News Ultra processed food consumption cancer risk cancer mortality large scale prospective analysis within Biobank Lancet Ultraproces', 'study TIAA Institute found that only adults have handle long they could potentially live', 'January American Perspectives Survey sheds some light dating preferences experiences perspectives national survey more than adults older including nearly single adults finds that Americans have strong dating', 'Pfizer topped Wall Street revenue estimates third quarter Moreover company updated guidance fiscal Analysts expect stock rise more than', 'failure collective willpower that jeopardising health diet food that culturally familiar nutrition super availableWestern culture bears weight that struggles shift recent stories perhaps expose', 'River Nice doesn believe stock market ethical they help clients discover harm reducing techniques that lead ethical investments', 'Hobbs outlines inaccurate risk assessments young woman murderer while Sarah Compton says nothing changed since murder brother Your article Probation service ministers have blood hands Zara Aleena family', 'families sick children have been pushed into poverty acc ...
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1061693948.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   adult_income_api = pd.read_csv(filename, error_bad_lines=False)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\akith\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

# %%
import numpy as np
def normalize_document(doc):
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I | re.A)
    doc = doc.lower()
    doc = doc.strip()
    # tokenize document
    tokens = wpt.tokenize(doc)
    # filter stopwords out of document
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # re-create document from filtered tokens
    doc = ' '.join(filtered_tokens)
    return doc


normalize_corpus = np.vectorize(normalize_document)

# %%
norm_corpus = normalize_corpus(HeadlineLIST)

# %%
temp = pd.DataFrame()

# %%
temp_1 = temp.append(norm_corpus[0].split()).T
for i in range(1,len(norm_corpus)):
    temp_2 = temp.append(norm_corpus[i].split()).T
    temp_1 = pd.concat([temp_1,temp_2])
# Out:
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_1 = temp.append(norm_corpus[0].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1722674452.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_2 = temp.append(norm_corpus[i].split()).T

# %%
temp_1['label'] = 'Adults_Income'
temp_1
# Out:
#               0              1          2             3           4  \
# 0     fertility          rates  declining       growing       share
# 0        health           care     lagged         peers       years
# 0   campaigners           call  ministers         allow  vulnerable
# 0         nimby           born  hampshire      michigan    northern
# 0          take           dink    dinkwad        double      income
# ..          ...            ...        ...           ...         ...
# 0      partisan  congressional     budget        office   cautioned
# 0        recent          years       huge        rising      demand
# 0        across        spheres       life  evolutionary    mismatch
# 0         judge        matthew  kacsmaryk       amassed      litany
# 0         could     concerning    climate        change   terrorism
#
#                5             6         7             8             9  ...  \
# 0         adults          plan  children           NaN           NaN  ...
# 0       pandemic          made    things         worse           NaN  ...
# 0         people        second    chance          goes  unclaimedone  ...
# 0     california     perfected     state  hillsborough    california  ...
# 0           kids      american     dream           NaN           NaN  ...
# ..           ...           ...       ...           ...           ...  ...
# 0       historic       federal      debt       default         could  ...
# 0         donkey         hides     china          used          make  ...
# 0         wealth  consistently  provides        buffer        social  ...
# 0    contentious       rulings      less          four  yearsmatthew  ...
# 0   homelessness       limited    access  reproductive        rights  ...
#
#            19         20       21          22       23         24  \
# 0         NaN        NaN      NaN         NaN      NaN        NaN
# 0         NaN        NaN      NaN         NaN      NaN        NaN
# 0       bills  according  figures       total     vouc        NaN
# 0     average     income      NaN         NaN      NaN        NaN
# 0         NaN        NaN      NaN         NaN      NaN        NaN
# ..        ...        ...      ...         ...      ...        ...
# 0         NaN        NaN      NaN         NaN      NaN        NaN
# 0   extracted     donkey    hides       mixed    herbs  ingredien
# 0         NaN        NaN      NaN         NaN      NaN        NaN
# 0      strong   language    every  democratic  senator    opposed
# 0         NaN        NaN      NaN         NaN      NaN        NaN
#
#               25   26   27          label
# 0            NaN  NaN  NaN  Adults_Income
# 0            NaN  NaN  NaN  Adults_Income
# 0            NaN  NaN  NaN  Adults_Income
# 0            NaN  NaN  NaN  Adults_Income
# 0            NaN  NaN  NaN  Adults_Income
# ..           ...  ...  ...            ...
# 0            NaN  NaN  NaN  Adults_Income
# 0            NaN  NaN  NaN  Adults_Income
# 0            NaN  NaN  NaN  Adults_Income
# 0   confirmation  NaN  NaN  Adults_Income
# 0            NaN  NaN  NaN  Adults_Income
#
# [100 rows x 29 columns]

# %% [markdown]
# **ADULTS INCOME & EDUCATION**

# %%
import requests

url = ('https://newsapi.org/v2/everything?''q=education&''apiKey=18071091481841b1910d5ae638bfef59')

response = requests.get(url)

print(response.json)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
jsontxt = response.json()

# %%
filename="Education_headlines.csv"
MyFILE=open(filename,"w")
WriteThis="Date,Source,Title,Headline\n"
MyFILE.write(WriteThis)
MyFILE.close()

# %%
MyFILE=open(filename, "a")

# %%
import re

for items in jsontxt["articles"]:
    Source=items["source"]["id"]    
    Date=items["publishedAt"]
    NewDate=Date.split("T")
    Date=NewDate[0]
    ## CLEAN the Title
    ##Replace punctuation with space
    # Accept one or more copies of punctuation         
    # plus zero or more copies of a space
    # and replace it with a single space
    Title=items["title"]
    Title=re.sub(r'[,.;@#?!&$\-\']+', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(' +', ' ', Title, flags=re.IGNORECASE)
    Title=re.sub(r'\"', ' ', Title, flags=re.IGNORECASE)
    
    # and replace it with a single space
    ## NOTE: Using the "^" on the inside of the [] means
    ## we want to look for any chars NOT a-z or A-Z and replace
    ## them with blank. This removes chars that should not be there.
    Title=re.sub(r'[^a-zA-Z]', " ", Title, flags=re.VERBOSE)
    Title=Title.replace(',', '')
    Title=' '.join(Title.split())
    Title=re.sub("\n|\r", "", Title)
    ##----------------------------------------------------------
    
    Headline=items["description"]
    Headline=re.sub(r'[,.;@#?!&$\-\']+', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(' +', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'\"', ' ', Headline, flags=re.IGNORECASE)
    Headline=re.sub(r'[^a-zA-Z]', " ", Headline, flags=re.VERBOSE)
    ## Be sure there are no commas in the headlines or it will
    ## write poorly to a csv file....
    Headline=Headline.replace(',', '')
    Headline=' '.join(Headline.split())
    Headline=re.sub("\n|\r", "", Headline)
    
    ### AS AN OPTION - remove words of a given length............
    Headline = ' '.join([wd for wd in Headline.split() if len(wd)>3])
    WriteThis=str(Date)+","+str(Source)+","+ str(Title) + "," + str(Headline) + "\n"
    
    MyFILE.write(WriteThis)
    
## CLOSE THE FILE
MyFILE.close()

# %%
education_api = pd.read_csv(filename, error_bad_lines=False)
print(education_api.head())
# iterating the columns 
for col in education_api.columns: 
    print(col) 
    
print(education_api["Headline"])

## REMOVE any rows with NaN in them
education_api = education_api.dropna()
print(education_api["Headline"])

### Tokenize and Vectorize the Headlines
## Create the list of headlines
HeadlineLIST=[]
for next1 in education_api["Headline"]:
    HeadlineLIST.append(next1)

print("The headline list is")
print(HeadlineLIST)
# Out:
#          Date    Source                                              Title  \
# 0  2023-01-23     wired  India s Public Education App Exposed Millions ...
# 1  2023-02-14  bbc-news  Ismail Mashal Fears for campaigning academic a...
# 2  2023-01-28   reuters  Afghan female students not allowed to sit univ...
# 3  2023-01-25       cnn  Opinion Minors rights can t be left up to thei...
# 4  2023-01-30      None  Last minute talks to start in bid to avert tea...
#
#                                             Headline
# 0  mandatory exposed personal information student...
# 1  Professor Ismail Mashal outspoken critic Talib...
# 2  Taliban Ministry Higher Education ordered priv...
# 3  Some most contentious debates American educati...
# 4  Union leaders meet education secretary before ...
# Date
# Source
# Title
# Headline
# 0     mandatory exposed personal information student...
# 1     Professor Ismail Mashal outspoken critic Talib...
# 2     Taliban Ministry Higher Education ordered priv...
# 3     Some most contentious debates American educati...
# 4     Union leaders meet education secretary before ...
#                             ...
# 95    true object education like that every other mo...
# 96    British public have been warned expect signifi...
# 97    After loud delay responded decision Florida De...
# 98    Vero lineup makes education debut along with t...
# 99    Teacher Abigail Zwerner left with serious inju...
# Name: Headline, Length: 100, dtype: object
# 0     mandatory exposed personal information student...
# 1     Professor Ismail Mashal outspoken critic Talib...
# 2     Taliban Ministry Higher Education ordered priv...
# 3     Some most contentious debates American educati...
# 4     Union leaders meet education secretary before ...
#                             ...
# 95    true object education like that every other mo...
# 96    British public have been warned expect signifi...
# 97    After loud delay responded decision Florida De...
# 98    Vero lineup makes education debut along with t...
# 99    Teacher Abigail Zwerner left with serious inju...
# Name: Headline, Length: 100, dtype: object
# The headline list is
# ['mandatory exposed personal information students teachers across country over year', 'Professor Ismail Mashal outspoken critic Taliban restrictions women education', 'Taliban Ministry Higher Education ordered private universities Afghanistan allow female students university entrance exams next month underscoring policy restrict women from tertiary education', 'Some most contentious debates American education among them what kinds stories allowed classroom teachers should teach history navigate LGBTQ issues when there states that seek them from discuss', 'Union leaders meet education secretary before planned action Wednesday dispute over politics live latest news updates Union leaders hold last minute talks with government avert strike action teachers', 'Three parents share their views strike tens thousands teachers England WalesMore than teachers England Wales taking part strike organised largest education union education secretary Gillian', 'George Santos previously been caught lying about work history religion education more', 'There harmful disconnect between Tories education policy country economic social needs says Michele Gregson Plus letters from Mike Tucker OrslerAs your editorial Guardian view arts education creativity crisis', 'Acer announced four Chromebooks which will available starting April These education focused offering balance power portability durability', 'Florida Department Education said course inexplicably contrary Florida significantly lacks educational value', 'record breaking singer back with sixth album discusses deprivation domestic violence feeling triumphant after stage fright surgery What your favourite track Shania Twain asks about album speaking over video call', 'family judge accuses Gillian Keegan complacency bordering cynicism over severe shortages England WalesThe country most senior family judge accused education secretary complacency bordering cynicism scathing judgment', 'Taliban denies women access schooling there been rise students being married ease family povertyIt weeks since Taliban closed door girls education across Afghanistan Zeina last vestiges hope', 'College Board developer standardized tests criteria determine college readiness students denounced state Florida Department Education playing political games Florida Desantis conducted relentless', 'joint secretary says teachers will back down rise negotiations with government reach stalemateSchools England look further disruption over coming weeks after talks avert planned strike action teachers ended failure', 'report details network dozens Russian camps aimed giving children Moscow views with some children detained indefinitely Ukraine coverage least children from Ukraine have attended Russian education', 'African American studies course high school students that released Wednesday does include material that Florida conservative governor said pushed liberal agenda latest development fierce debate about politics education', 'Trade jobs that require less education much lower cost empty many parents remain wary programs that lead four year degree', 'DACA students aren eligible federal loans like born students there alternatives DACA students finance their education', 'Education Department asked input proposals reform student loan repayment batch commenters oppose relief responded', 'Professor Christian Terwiesch said would have received grade exam thinks help improve education students', 'This administration knows full well that cannot wave magic wand cancel student loans Foxx education committee chair told Insider', 'Jane Lunnon head teacher year Alleyn School told Insider Everyone talking about education', 'Members spoonie community connect over what like have chronic illness they offer each other education support', 'Biden Education Department launched website help student loan borrowers think they were defrauded their school debt relief', 'Thomas Massie touted bill Education Department explanation Insider left more questions ...
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\1841685384.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   education_api = pd.read_csv(filename, error_bad_lines=False)

# %%
norm_corpus = normalize_corpus(HeadlineLIST)

# %%
norm_corpus
# Out:
# array(['mandatory exposed personal information students teachers across country year',
#        'professor ismail mashal outspoken critic taliban restrictions women education',
#        'taliban ministry higher education ordered private universities afghanistan allow female students university entrance exams next month underscoring policy restrict women tertiary education',
#        'contentious debates american education among kinds stories allowed classroom teachers teach history navigate lgbtq issues states seek discuss',
#        'union leaders meet education secretary planned action wednesday dispute politics live latest news updates union leaders hold last minute talks government avert strike action teachers',
#        'three parents share views strike tens thousands teachers england walesmore teachers england wales taking part strike organised largest education union education secretary gillian',
#        'george santos previously caught lying work history religion education',
#        'harmful disconnect tories education policy country economic social needs says michele gregson plus letters mike tucker orsleras editorial guardian view arts education creativity crisis',
#        'acer announced four chromebooks available starting april education focused offering balance power portability durability',
#        'florida department education said course inexplicably contrary florida significantly lacks educational value',
#        'record breaking singer back sixth album discusses deprivation domestic violence feeling triumphant stage fright surgery favourite track shania twain asks album speaking video call',
#        'family judge accuses gillian keegan complacency bordering cynicism severe shortages england walesthe country senior family judge accused education secretary complacency bordering cynicism scathing judgment',
#        'taliban denies women access schooling rise students married ease family povertyit weeks since taliban closed door girls education across afghanistan zeina last vestiges hope',
#        'college board developer standardized tests criteria determine college readiness students denounced state florida department education playing political games florida desantis conducted relentless',
#        'joint secretary says teachers back rise negotiations government reach stalemateschools england look disruption coming weeks talks avert planned strike action teachers ended failure',
#        'report details network dozens russian camps aimed giving children moscow views children detained indefinitely ukraine coverage least children ukraine attended russian education',
#        'african american studies course high school students released wednesday include material florida conservative governor said pushed liberal agenda latest development fierce debate politics education',
#        'trade jobs require less education much lower cost empty many parents remain wary programs lead four year degree',
#        'daca students eligible federal loans like born students alternatives daca students finance education',
#        'education department asked input proposals reform student loan repayment batch commenters oppose relief responded',
#        'professor christian terwiesch said would received grade exam thinks help improve education students',
#        'administration knows full well cannot wave magic wand cancel student loans foxx education committee chair told insider',
#        'jane lunnon head teacher year alleyn school told insider everyone talking education',
#        'members spoonie community connect like chronic illness offer education support',
#        'biden education department launched website help student loan borrowers think defrauded school debt relief',
#        'thomas massie touted bill education department explanation insider left questions answers',
#        'days strike action grady general secretary demands draining campus conditionsstriking university staff determined secure deal tackles burnout makes working lives liveable grady general secretary',
#        'tennessee university professor recently made case undergraduate mathematics education discriminatory queer transgender students',
#        'child ramzan fight education almost cost life worldwide million children school urgently need help gordon brown chairman education cannot wait fund prime minister',
#        'parenting advice illness life postpartum education',
#        'nato members meet brussels discuss sending supplies ukraine report confirms least russian camps aimed giving children moscow views russia ukraine glance know invasion hello welcome',
#        'independent auditor concur foxx claims biden lied student loan costs concerns certain estimates',
#        'supreme court justice brett kavanaugh joined growing chorus news world report school rankings critics saying talk week university notre dame school annual list fails accurately gauge',
#        'britain facing sweeping wave href world biggest strike action years teachers civil servants walk industrial action decades workers across sectors including healthcare transport education',
#        'must stand defend rights afghan women girls professor kabul university says',
#        'desantis racist advanced placement course african american studies backfired fascist restrictions floridians allowed read discuss inspired chicago book publisher distribute free books black history',
#        'schools nationwide banning openai chatgpt experts future artificial intelligence education',
#        'refugees worked alongside british army taliban took power afghan refugees protested plans move miles london yorkshire amid claims could challenge government decision courts carr',
#        'parents rejoice rare florida education policy struck decades optional menstrual questions student athletes',
#        'ideologues like desantis angry politics education angry politics monopolythe rightwing governor florida desantis administration recently blocked proposed black studies course advanced placeme',
#        'year pupil milly bell headteacher elisabeth broers united support teachers going strike weekafter three years disrupted education form home learning bubbles incessant mask wearing thing classmates want',
#        'government fail target pupils england reaching standard research findsrishi sunak warned target boost number children entering secondary school expected standards reading writing',
#        'mother says threatened shoot daughter class police called',
#        'december survey democratic pollsters hart research associates parents said culture wars distraction schools primary mission education',
#        'famous century poem ramcharitmanas become battle ground claims discriminatory',
#        'social mobility commission says students informed earnings implications course choicesstudents given details courses study leaving school might affect employment prospects suggested',
#        'controversial chatbot chatgpt sparked debate artificial intelligence education',
#        'creator beloved children education series sesame street lloyd morrisett died',
#        'matrix movies brought reeves chad stahelski together killing fourth john wick still keeping technology check',
#        'lelapa building research serve african businesses nonprofits hope locally grown algorithms better serve communities',
#        'china southwestern province sichuan drop restrictions unmarried people children part broader attempt government boost country plummeting birth rate',
#        'republican presidential candidate makes comments hampshire controversial signed governor desantisrepublican presidential candidate nikki haley told hampshire audience controversial education signed',
#        'quality education exposure different cultures identified preventive factors african surveyhuman rights abuses committed security forces economic deprivation among important drivers recruitment extremist groups',
#        'education minister jason clare responded media reports intends visit family australian partner bianca censori next week',
#        'malnourished bird found manhattan madison square park',
#        'government declines call legal duty care students death natasha abrahart parents natasha abrahart took life studying university bristol reacted absolute horror',
#        'general secretary says ahead wednesday strike teachers undervalued underpaid overworked teachers tether mary bousted national education union said government called last ditch talks monda',
#        'opposition says province missing action munfa strike vocm picketing cancelled classes begin deadline passes labour dispute cape breton university strike enters four news atlantic',
#        'wharton professor christian terwiesch tested chatgpt questions final exam operations management',
#        'attorney crump announced potential lawsuit florida governor state rejected advanced placement course college board says revise',
#        'easy people riled panicked kids changing culture lost innocence exactly right doingyou could forgiven losing track lurid inventive ways desantis florida govern',
#        'utah republican governor saturday signed bills youth receiving gender affirming health care allow families receive scholarships education outside public school system measures part larger nationwide',
#        'fumio kishida says japan brink able function falling birth rate',
#        'prof ismail mashal outspoken critic taliban restrictions women education',
#        'gillian anderson rose fame files agent dana scully asking women anonymously tell sexual fantasies days anderson plays therapist netflix series education launching major exploration women',
#        'reason workers quiet quitting cannot afford loud quitting labor unions experience resurgence interest manufacturing higher education service industry transportation capitalists managers compl',
#        'children young four months sent parents believed temporary holiday camps many returned according report',
#        'stanford joins growing number schools like princeton harvard working reduce student debt burden graduates',
#        'state schools close permanently extensive safety concernsat least state schools england forced close either partially entirely last three years buildings deemed unsafe',
#        'move follows agreement employers lowest paid workers review salary gradesstrikes university support staff next weeks called breakthrough negotiations unison announced five unions unison',
#        'google calendar update helps schedule meetings across calendars much straightforward organized manner',
#        'simon bull asks discrimination state educated outlawed readers write oxbridge eton dominationlike john harris went comprehensive school oxbridge experience similar understand',
#        'state board education said restricting school libraries displaying lending books vetted applies books displayed classrooms',
#        'exclusive report denounces postcode lottery barely half institutions offer form language teachingbusiness groups language experts calling ministers make linguistic skills core part vocational training research found',
#        'supreme court applies written cancellation warren said student debt relief',
#        'deliberating considering kind alternative approach white house official told reporters student debt cancellation',
#        'taliban doubling women education reinforcing message private universities afghan women barred taking university entry exams',
#        'college board released wednesday official framework advanced placement course african american studies florida desantis earlier denounced imposing political agenda',
#        'police said year woman provided false birth certificate brunswick board education trying enroll high school',
#        'hipkins built reputation minister zealand covid strategy',
#        'hiring spree kind official changing higher education america',
#        'john cassidy writes bernie sanders political plans sanders chair senate committee health education labor pensions',
#        'organization released curriculum advanced placement course florida rejected pilot revisions removed units black feminist literary thought black lives matter',
#        'data shows sharp decline students italy germany france brexit seen primary deterrentthe number students enrolling british universities halved since brexit sharp declines scholars italy germany',
#        'cost living crisis means young people earning learn could good bank balancesdespite stereotypes university students living ivory towers affected cost living crisis like',
#        'speech enterprise education employment everywhere contained vague empty promisesbrexit shake britons comfortable torpor turn risktakers forefront digital revolution jeremy',
#        'internet valuable source knowledge education amusement kids time come problems inappropriate material cyberbullying online harassment websites hazardous children becau',
#        'teacher accused cutting hair least students following relaxing hair regulations last monthactivists thailand called clearer guidance enforcement stop humiliating punishment haircuts schools teacher',
#        'dedicated teaching exhaustion falling real terms sense social crisis pushed actteachers england wales strike wednesday hour talks union leaders government failed find',
#        'raising maintenance loans means students back food books says reportthe department education admitted students england face negative impact refusal increase support line inflation sayin',
#        'base rate reaches hear people concerned rising mortgage costschris felix hill wife adeline steeple essex struggling keep alive dream becoming homeowners demoralising house price',
#        'gainful employment rule would strip federal schools offer degrees live financial promises',
#        'feminist groups public services mainly female workforces rights affected draconian lawfeminist campaign groups raised alarm government anti strike bill enforce minimum service levels saying',
#        'several underlying factors cause success encouragement around among important',
#        'framework course makes content topics like black lives matter queer studies optional classrooms nationwide',
#        'true object education like every moral process generation happiness happiness individual first place individuals universally happy species would happy',
#        'british public warned expect significant disruption coordinated strike across involving teachers civil servants border force staff train drivers teachers took streets demanding rise',
#        'loud delay responded decision florida department education refuse recognize african american history legitimate course reported statement clarifies asserts legitimacy impo',
#        'vero lineup makes education debut along three chromebooks',
#        'teacher abigail zwerner left serious injuries shot classroom'],
#       dtype='<U215')

# %%
temp = pd.DataFrame()

# %%
temp_3 = temp.append(norm_corpus[0].split()).T
for i in range(1,len(norm_corpus)):
    temp_4 = temp.append(norm_corpus[i].split()).T
    temp_3 = pd.concat([temp_3,temp_4])
# Out:
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_3 = temp.append(norm_corpus[0].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T
# C:\Users\akith\AppData\Local\Temp\ipykernel_24488\3651831735.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_4 = temp.append(norm_corpus[i].split()).T

# %%
temp_3['label'] = 'Education'
temp_3
# Out:
#               0         1          2            3            4           5  \
# 0     mandatory   exposed   personal  information     students    teachers
# 0     professor    ismail     mashal    outspoken       critic     taliban
# 0       taliban  ministry     higher    education      ordered     private
# 0   contentious   debates   american    education        among       kinds
# 0         union   leaders       meet    education    secretary     planned
# ..          ...       ...        ...          ...          ...         ...
# 0          true    object  education         like        every       moral
# 0       british    public     warned       expect  significant  disruption
# 0          loud     delay  responded     decision      florida  department
# 0          vero    lineup      makes    education        debut       along
# 0       teacher   abigail    zwerner         left      serious    injuries
#
#                6            7          8          9  ...          18     19  \
# 0         across      country       year        NaN  ...         NaN    NaN
# 0   restrictions        women  education        NaN  ...         NaN    NaN
# 0   universities  afghanistan      allow     female  ...    restrict  women
# 0        stories      allowed  classroom   teachers  ...         NaN    NaN
# 0         action    wednesday    dispute   politics  ...      minute  talks
# ..           ...          ...        ...        ...  ...         ...    ...
# 0        process   generation  happiness  happiness  ...       happy    NaN
# 0    coordinated       strike     across  involving  ...    teachers   took
# 0      education       refuse  recognize    african  ...  legitimacy   impo
# 0          three  chromebooks        NaN        NaN  ...         NaN    NaN
# 0           shot    classroom        NaN        NaN  ...         NaN    NaN
#
#             20         21      22      23        24   25   26      label
# 0          NaN        NaN     NaN     NaN       NaN  NaN  NaN  Education
# 0          NaN        NaN     NaN     NaN       NaN  NaN  NaN  Education
# 0     tertiary  education     NaN     NaN       NaN  NaN  NaN  Education
# 0          NaN        NaN     NaN     NaN       NaN  NaN  NaN  Education
# 0   government      avert  strike  action  teachers  NaN  NaN  Education
# ..         ...        ...     ...     ...       ...  ...  ...        ...
# 0          NaN        NaN     NaN     NaN       NaN  NaN  NaN  Education
# 0      streets  demanding    rise     NaN       NaN  NaN  NaN  Education
# 0          NaN        NaN     NaN     NaN       NaN  NaN  NaN  Education
# 0          NaN        NaN     NaN     NaN       NaN  NaN  NaN  Education
# 0          NaN        NaN     NaN     NaN       NaN  NaN  NaN  Education
#
# [100 rows x 28 columns]

# %%
transactiondata = pd.concat([temp_1,temp_3])

# %%
transactiondata
# Out:
#               0        1          2          3            4           5  \
# 0     fertility    rates  declining    growing        share      adults
# 0        health     care     lagged      peers        years    pandemic
# 0   campaigners     call  ministers      allow   vulnerable      people
# 0         nimby     born  hampshire   michigan     northern  california
# 0          take     dink    dinkwad     double       income        kids
# ..          ...      ...        ...        ...          ...         ...
# 0          true   object  education       like        every       moral
# 0       british   public     warned     expect  significant  disruption
# 0          loud    delay  responded   decision      florida  department
# 0          vero   lineup      makes  education        debut       along
# 0       teacher  abigail    zwerner       left      serious    injuries
#
#               6            7             8             9  ...       19  \
# 0          plan     children           NaN           NaN  ...      NaN
# 0          made       things         worse           NaN  ...      NaN
# 0        second       chance          goes  unclaimedone  ...    bills
# 0     perfected        state  hillsborough    california  ...  average
# 0      american        dream           NaN           NaN  ...      NaN
# ..          ...          ...           ...           ...  ...      ...
# 0       process   generation     happiness     happiness  ...      NaN
# 0   coordinated       strike        across     involving  ...     took
# 0     education       refuse     recognize       african  ...     impo
# 0         three  chromebooks           NaN           NaN  ...      NaN
# 0          shot    classroom           NaN           NaN  ...      NaN
#
#            20         21     22    23   24   25   26   27          label
# 0         NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN  Adults_Income
# 0         NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN  Adults_Income
# 0   according    figures  total  vouc  NaN  NaN  NaN  NaN  Adults_Income
# 0      income        NaN    NaN   NaN  NaN  NaN  NaN  NaN  Adults_Income
# 0         NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN  Adults_Income
# ..        ...        ...    ...   ...  ...  ...  ...  ...            ...
# 0         NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN      Education
# 0     streets  demanding   rise   NaN  NaN  NaN  NaN  NaN      Education
# 0         NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN      Education
# 0         NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN      Education
# 0         NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN      Education
#
# [200 rows x 29 columns]

# %%
transactiondata = transactiondata.iloc[: , :-1]

# %%
transactiondata.to_csv("transactions_data.csv", index = False, header = False)

# %%
transactiondata
# Out:
#              0        1          2          3            4           5   \
# 0     fertility    rates  declining    growing        share      adults
# 0        health     care     lagged      peers        years    pandemic
# 0   campaigners     call  ministers      allow   vulnerable      people
# 0         nimby     born  hampshire   michigan     northern  california
# 0          take     dink    dinkwad     double       income        kids
# ..          ...      ...        ...        ...          ...         ...
# 0          true   object  education       like        every       moral
# 0       british   public     warned     expect  significant  disruption
# 0          loud    delay  responded   decision      florida  department
# 0          vero   lineup      makes  education        debut       along
# 0       teacher  abigail    zwerner       left      serious    injuries
#
#              6            7             8             9   ...          18  \
# 0          plan     children           NaN           NaN  ...         NaN
# 0          made       things         worse           NaN  ...         NaN
# 0        second       chance          goes  unclaimedone  ...        help
# 0     perfected        state  hillsborough    california  ...       based
# 0      american        dream           NaN           NaN  ...         NaN
# ..          ...          ...           ...           ...  ...         ...
# 0       process   generation     happiness     happiness  ...       happy
# 0   coordinated       strike        across     involving  ...    teachers
# 0     education       refuse     recognize       african  ...  legitimacy
# 0         three  chromebooks           NaN           NaN  ...         NaN
# 0          shot    classroom           NaN           NaN  ...         NaN
#
#          19         20         21     22    23   24   25   26   27
# 0       NaN        NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 0       NaN        NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 0     bills  according    figures  total  vouc  NaN  NaN  NaN  NaN
# 0   average     income        NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 0       NaN        NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN
# ..      ...        ...        ...    ...   ...  ...  ...  ...  ...
# 0       NaN        NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 0      took    streets  demanding   rise   NaN  NaN  NaN  NaN  NaN
# 0      impo        NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 0       NaN        NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN
# 0       NaN        NaN        NaN    NaN   NaN  NaN  NaN  NaN  NaN
#
# [200 rows x 28 columns]

# %% [markdown]
# **K-Means Clustering**

# %%
df.to_csv("df.csv", index = False)

# %%
numeric_df = df[['age','educational-num','capital-gain','capital-loss','hours-per-week']]

# %%
numeric_df.to_csv("numeric_df.csv", index = False)

# %%
from sklearn.preprocessing import StandardScaler 
numeric_df = StandardScaler().fit_transform(numeric_df)

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
import numpy as np

distortions = []
inertias = []
mapping1 = {}
mapping2 = {}
K = range(1, 10)
  
for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(numeric_df)
    kmeanModel.fit(numeric_df)
  
    distortions.append(sum(np.min(cdist(numeric_df, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / numeric_df.shape[0])
    inertias.append(kmeanModel.inertia_)
  
    mapping1[k] = sum(np.min(cdist(numeric_df, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / numeric_df.shape[0]
    mapping2[k] = kmeanModel.inertia_

# %%
for key, val in mapping1.items():
    print(f'{key} : {val}')
# Out:
# 1 : 1.7839121745166706
# 2 : 1.6188644935651826
# 3 : 1.5540852731070165
# 4 : 1.3467431268372423
# 5 : 1.1985299113766625
# 6 : 1.11603820624091
# 7 : 1.029313961377612
# 8 : 0.9741319562867189
# 9 : 0.9326789105566479

# %%
plt.figure(figsize=(7,5))
plt.plot(K, distortions, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Distortion')
plt.title('The Elbow Method using Distortion')
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA().fit(numeric_df)

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (7,5)

fig, ax = plt.subplots()
xi = np.arange(1, 6, step=1)
y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(xi, y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.xticks(np.arange(0, 15, step=2)) #change from 0-based array index to 1-based human-readable label
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
#PCA 
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(numeric_df)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

# %%
plt.figure(figsize=(7,5))
kmeans = KMeans(n_clusters = 4)
label = kmeans.fit_predict(principalDf)
plt.scatter(df['age'], df['educational-num'], c = label, s= 50, cmap = 'viridis' )
plt.xlabel("Age") 
plt.ylabel("Years of Education") 
plt.title("K-Means Clustering based on K=4")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering based on K=4')

# %%
plt.figure(figsize=(7,5))
kmeans = KMeans(n_clusters = 5)
label = kmeans.fit_predict(principalDf)
plt.scatter(df['age'], df['educational-num'], c = label, s= 50, cmap = 'viridis' )
plt.xlabel("Age") 
plt.ylabel("Years of Education") 
plt.title("K-Means Clustering based on K=5")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering based on K=5')

# %%
plt.figure(figsize=(7,5))
kmeans = KMeans(n_clusters = 3)
label = kmeans.fit_predict(principalDf)
plt.scatter(df['age'], df['educational-num'], c = label, s= 50, cmap = 'viridis' )
plt.xlabel("Age") 
plt.ylabel("Years of Education") 
plt.title("K-Means Clustering based on K=3")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering based on K=3')

# %%
type(numeric_df)
# Out:
# numpy.ndarray

# %%
numeric_df.shape
# Out:
# (45175, 5)

# %%
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
numeric_df, true_labels = make_blobs(n_samples=200, centers=3, cluster_std=2.75, random_state=None)

# %%
true_labels[:20]
# Out:
# array([0, 0, 0, 1, 1, 1, 1, 2, 1, 0, 2, 2, 0, 2, 1, 2, 0, 2, 1, 0])

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(numeric_df)

# %%
kmeans = KMeans(init="random", n_clusters=3, n_init=10, max_iter=300, random_state=42)

# %%
kmeans.fit(scaled_features)
# Out:
# KMeans(init='random', n_clusters=3, random_state=42)

# %%
kmeans.inertia_
# Out:
# 78.23396363892545

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.633852  , -0.90108851],
#        [ 1.17314387, -0.41676745],
#        [-0.62966261,  1.28272086]])

# %%
kmeans.n_iter_
# Out:
# 4

# %%
kmeans.labels_[:5]
# Out:
# array([0, 0, 0, 2, 2])

# %%
kmeans_kwargs = {"init": "random", "n_init": 10, "max_iter": 300, "random_state": 42,}

# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
 kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
 kmeans.fit(scaled_features)
 sse.append(kmeans.inertia_)
# Out:
# C:\Users\akith\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(range(1, 11), sse, curve="convex", direction="decreasing")

# %%
kl.elbow
# Out:
# 3

# %%
 # A list holds the silhouette coefficients for each k
silhouette_coefficients = []
 # Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 11), silhouette_coefficients)
plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %%
# Instantiate k-means and dbscan algorithms
kmeans = KMeans(n_clusters=2)
# Fit the algorithms to the features
kmeans.fit(scaled_features)
# Compute the silhouette scores for each algorithm
kmeans_silhouette = silhouette_score(scaled_features, kmeans.labels_).round(2)

# %%
kmeans_silhouette
# Out:
# 0.51
